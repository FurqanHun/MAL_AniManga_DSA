# %%
import csv
import pandas as pd

# %%
manga_df=pd.read_csv('MAL_Top_MANGA\Final_MAL_Scrap.csv')
manga_df.head()
anime_df=pd.read_csv('MAL_Top_ANIME\Final_MAL_Scrap.csv')
anime_df.head()

# %%
#add the column named Page in manga df
manga_df['Page']='Top Manga'
manga_df.head()
# Out:
#                                              Title   Type  Score  Score Count  \
# 0                                          Berserk  Manga   9.47       329632
# 1  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  Manga   9.30       155665
# 2                                         Vagabond  Manga   9.24       135419
# 3                                        One Piece  Manga   9.22       365241
# 4                                          Monster  Manga   9.15        93420
#
#    Members  Rank  Popularity  \
# 0   662227     1           1
# 1   255066     2          26
# 2   362718     3          15
# 3   596855     4           3
# 4   235224     5          29
#
#                                               Genres  \
# 0  Action, Adventure, Award Winning, Drama, Fanta...
# 1  Action, Adventure, Mystery, Supernatural, Hist...
# 2  Action, Adventure, Award Winning, Historical, ...
# 3                Action, Adventure, Fantasy, Shounen
# ...

# %%
df=pd.concat([manga_df,anime_df])
df.head()
# Out:
#                                              Title   Type  Score  Score Count  \
# 0                                          Berserk  Manga   9.47       329632
# 1  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  Manga   9.30       155665
# 2                                         Vagabond  Manga   9.24       135419
# 3                                        One Piece  Manga   9.22       365241
# 4                                          Monster  Manga   9.15        93420
#
#    Members  Rank  Popularity  \
# 0   662227     1           1
# 1   255066     2          26
# 2   362718     3          15
# 3   596855     4           3
# 4   235224     5          29
#
#                                               Genres  \
# 0  Action, Adventure, Award Winning, Drama, Fanta...
# 1  Action, Adventure, Mystery, Supernatural, Hist...
# 2  Action, Adventure, Award Winning, Historical, ...
# 3                Action, Adventure, Fantasy, Shounen
# ...

# %%
#saving the dataframe
df.to_csv('MERGED_MAL_Scrap.csv',index=False)

# %%
#length of dataframe
len(df)
# Out:
# 9684

# %%
# renaming authors column to authors/studio
# import pandas as pd
# df = pd.read_csv('MERGED_MAL_Scrap.csv')
# df.columns = ['Title', 'Type', 'Score', 'Score Count', 'Members', 'Rank', 'Popularity', 'Genres', 'Authors/Studio', 'Synopsis', 'Link', 'Date', 'Page']
# df.to_csv('MERGED_MAL_Scrap.csv', index=False)
